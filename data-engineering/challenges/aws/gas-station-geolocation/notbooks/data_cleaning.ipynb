# %%
import pandas as pd
import xml.etree.ElementTree as et
import numpy as np

# %% [markdown]
# #### Exploring data sources
#
# - [Web Free Mexico data site ](https://datos.gob.mx/)
# - [XML Data sets ](https://datos.gob.mx/busca/dataset/estaciones-de-servicio-gasolineras-y-precios-finales-de-gasolina-y-diesel)

# %%
df_places = pd.read_xml('../datasets/places.xml')
df_places.head(20)
# Out:
#     place_id                                           name  \
# 0       2039     ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.
# 1       2040             LAS MEJORES ESTACIONES, S.A DE C.V
# 2       2041                         DIAZ GAS, S.A. DE C.V.
# 3       2042                    COMBU-EXPRESS, S.A. DE C.V.
# 4       2043                         PETROMAX, S.A. DE C.V.
# 5       2044              ESTACION RAEL, S. DE R.L. DE C.V.
# 6       2045            MULTISERVICIOS LA PILARICA SA DE CV
# 7       2046                         PETROMAX, S.A. DE C.V.
# 8       2047              ESTACION RAEL, S. DE R.L. DE C.V.
# 9       2048                    ESTACION PIRU, S.A. DE C.V.
# 10      2049                         PETROMAX, S.A. DE C.V.
# 11      2050             AUTOSERVICIO BERLANGA S.A. DE C.V.
# 12      2051                         PETROMAX, S.A. DE C.V.
# 13      2052                     GRUPO OCTANO, S.A. DE C.V.
# 14      2053                      CIRCULO DOS, S.A. DE C.V.
# 15      2054                 Servicio Sevilla, S.A. de C.V.
# 16      2055                         PETROMAX, S.A. DE C.V.
# 17      2056              GASOLINERA HUITEPEC, S.A. DE C.V.
# 18      2057                         PETROMAX, S.A. DE C.V.
# 19      2058  ENERGIA Y SERVICIOS COORDINADOS, S.A. DE C.V.
#
#                 cre_id  location
# 0   PL/658/EXP/ES/2015       NaN
# 1   PL/902/EXP/ES/2015       NaN
# 2   PL/760/EXP/ES/2015       NaN
# 3   PL/825/EXP/ES/2015       NaN
# 4   PL/585/EXP/ES/2015       NaN
# 5   PL/842/EXP/ES/2015       NaN
# 6   PL/371/EXP/ES/2015       NaN
# 7   PL/439/EXP/ES/2015       NaN
# 8   PL/860/EXP/ES/2015       NaN
# 9   PL/897/EXP/ES/2015       NaN
# 10  PL/561/EXP/ES/2015       NaN
# 11  PL/797/EXP/ES/2015       NaN
# 12  PL/583/EXP/ES/2015       NaN
# 13  PL/366/EXP/ES/2015       NaN
# 14  PL/635/EXP/ES/2015       NaN
# 15  PL/868/EXP/ES/2015       NaN
# 16  PL/558/EXP/ES/2015       NaN
# 17  PL/887/EXP/ES/2015       NaN
# 18  PL/454/EXP/ES/2015       NaN
# 19  PL/890/EXP/ES/2015       NaN

# %%
df_places.count()
# Out:
# place_id    13802
# name        13802
# cre_id      13802
# location        0
# dtype: int64

# %%
df_prices = pd.read_xml('../datasets/prices.xml')
df_prices.head(20)
# Out:
#     place_id  gas_price
# 0      11703      20.43
# 1      11703      23.89
# 2      11702      25.30
# 3      11701      22.99
# 4      11700      23.95
# 5      11699      21.99
# 6      11699      24.14
# 7      11698      22.20
# 8      11698      24.50
# 9      11697      23.69
# 10     11697      23.89
# 11     11696      21.39
# 12     11696      23.49
# 13     11696      23.49
# 14     11695      23.69
# 15     11694      23.69
# 16      3153      19.99
# 17      3153      23.29
# 18      3153      23.49
# 19     11693      24.15

# %%
df_prices.count()
# Out:
# place_id     22366
# gas_price    22366
# dtype: int64

# %% [markdown]
# ### Refactoring data and cleaning data
#
# - Places location (place_id, lat, long )are within xml places data set
# - The prices of every gas type of every place (place_id, gas_type) are within xml prices data set.
#
# In order to make the data more readable and handful, It’s necessary to merge datasets and convert it into a pandas data frame.
#
# - [From xml to Pandas](https://datos.gob.mx/busca/dataset/estaciones-de-servicio-gasolineras-y-precios-finales-de-gasolina-y-diesel)

# %%
# Refactoring data for places XML file

xtree = et.parse("../datasets/places.xml")
xroot = xtree.getroot()

# Data frame cols and row
df_places_cols = ['place_id','name', 'latitude', 'longitude']
rows = []

# Read xml nodes
for node in xroot:
    place_id = node.attrib.get('place_id')
    name = node.find('name').text if node is not None else None
    location = node.find('location')
    lat = location.find('y').text if location is not None else None
    long = location.find('x').text if location is not None else None

    rows.append({
        'place_id':place_id,
        'name':name,
        'latitude':float(lat),
        'longitude':float(long)
    })

df_places_refactor = pd.DataFrame(rows, columns=df_places_cols)
df_places_refactor.head(20)
# Out:
#    place_id                                           name  latitude  \
# 0      2039     ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.  32.47641
# 1      2040             LAS MEJORES ESTACIONES, S.A DE C.V  20.30370
# 2      2041                         DIAZ GAS, S.A. DE C.V.  31.71947
# 3      2042                    COMBU-EXPRESS, S.A. DE C.V.  20.71413
# 4      2043                         PETROMAX, S.A. DE C.V.  26.03787
# 5      2044              ESTACION RAEL, S. DE R.L. DE C.V.  32.51342
# 6      2045           MULTISERVICIOS LA PILARICA SA DE CV   25.75580
# 7      2046                         PETROMAX, S.A. DE C.V.  25.77202
# 8      2047              ESTACION RAEL, S. DE R.L. DE C.V.  31.86546
# 9      2048                    ESTACION PIRU, S.A. DE C.V.  32.31202
# 10     2049                         PETROMAX, S.A. DE C.V.  25.65562
# 11     2050             AUTOSERVICIO BERLANGA S.A. DE C.V.  26.92554
# 12     2051                         PETROMAX, S.A. DE C.V.  25.83842
# 13     2052                     GRUPO OCTANO, S.A. DE C.V.  21.47390
# 14     2053                      CIRCULO DOS, S.A. DE C.V.  32.52790
# 15     2054                 Servicio Sevilla, S.A. de C.V.  19.58616
# 16     2055                         PETROMAX, S.A. DE C.V.  25.67880
# 17     2056              GASOLINERA HUITEPEC, S.A. DE C.V.  16.73187
# 18     2057                         PETROMAX, S.A. DE C.V.  26.01390
# 19     2058  ENERGIA Y SERVICIOS COORDINADOS, S.A. DE C.V.  24.02956
#
#     longitude
# 0  -116.92140
# 1   -99.74484
# 2  -106.45140
# 3  -103.30420
# 4   -98.29977
# 5  -117.07150
# 6  -108.96850
# 7  -100.29180
# 8  -116.60790
# 9  -117.04570
# 10 -100.18400
# 11 -101.41890
# 12  -97.44485
# 13 -105.19470
# 14 -117.02710
# 15  -99.19730
# 16 -100.23650
# 17  -92.65437
# 18  -98.20425
# 19 -104.62170

# %%
df_places_refactor.count()
# Out:
# place_id     13802
# name         13802
# latitude     13802
# longitude    13802
# dtype: int64

# %%
# Refactoring data for prices XML file

xtree = et.parse("../datasets/prices.xml")
xroot = xtree.getroot()

# Data frame cols and row
df_cols = ['place_id','regular', 'premium', 'diesel']
rows = []

# Read xml nodes
place_ids = dict() # to mange duplicate places
for node in xroot:
    place_id = node.attrib.get('place_id')
    children_iterator = node.find('gas_price').iter()
    gas_types = place_ids[place_id] if place_id in place_ids else {'regular': np.nan, 'premium':np.nan, 'diesel':np.nan}
    for item in children_iterator:
        gas_type = item.attrib.get('type')
        gas_types[gas_type] = item.text

    place_ids[place_id] = gas_types

for place_id,gas_types in place_ids.items():
    rows.append({
        'place_id':place_id,
        'regular':gas_types['regular'],
        'premium':gas_types['premium'],
        'diesel':gas_types['diesel']
    })

df_prices_refactor = pd.DataFrame(rows, columns=df_cols)
df_prices_refactor.head(20)
# Out:
#    place_id regular premium diesel
# 0     11703   20.43   23.89    NaN
# 1     11702    24.2     NaN    NaN
# 2     11701   17.89     NaN    NaN
# 3     11700   21.75     NaN    NaN
# 4     11699   21.99   24.14    NaN
# 5     11698    22.2     NaN   24.5
# 6     11697   22.09     NaN  23.69
# 7     11696   21.39   23.49  23.49
# 8     11695   22.09     NaN    NaN
# 9     11694   22.09     NaN    NaN
# 10     3153   19.99   23.49  23.29
# 11    11693   22.15   23.95  24.15
# 12    11692   22.12    23.5    NaN
# 13    11691   21.79   24.89  22.99
# 14    11690   22.09     NaN    NaN
# 15    11395   22.69   24.49  23.98
# 16    11394   22.59   24.79  23.99
# 17    11393   21.43     NaN    NaN
# 18    11392   22.39     NaN  24.49
# 19    11391   20.69   23.99  21.99

# %%
df_prices_refactor.count()
# Out:
# place_id    13303
# regular     13243
# premium      5102
# diesel       3857
# dtype: int64

# %%
# merging data frames by place_id

df_refactored = df_places_refactor.merge(df_prices_refactor,how='inner')
df_refactored.head(20)
# Out:
#    place_id                                           name  latitude  \
# 0      2039     ESTACION DE SERVICIO CALAFIA, S.A. DE C.V.  32.47641
# 1      2040             LAS MEJORES ESTACIONES, S.A DE C.V  20.30370
# 2      2041                         DIAZ GAS, S.A. DE C.V.  31.71947
# 3      2042                    COMBU-EXPRESS, S.A. DE C.V.  20.71413
# 4      2043                         PETROMAX, S.A. DE C.V.  26.03787
# 5      2044              ESTACION RAEL, S. DE R.L. DE C.V.  32.51342
# 6      2045           MULTISERVICIOS LA PILARICA SA DE CV   25.75580
# 7      2046                         PETROMAX, S.A. DE C.V.  25.77202
# 8      2047              ESTACION RAEL, S. DE R.L. DE C.V.  31.86546
# 9      2048                    ESTACION PIRU, S.A. DE C.V.  32.31202
# 10     2049                         PETROMAX, S.A. DE C.V.  25.65562
# 11     2050             AUTOSERVICIO BERLANGA S.A. DE C.V.  26.92554
# 12     2051                         PETROMAX, S.A. DE C.V.  25.83842
# 13     2052                     GRUPO OCTANO, S.A. DE C.V.  21.47390
# 14     2053                      CIRCULO DOS, S.A. DE C.V.  32.52790
# 15     2054                 Servicio Sevilla, S.A. de C.V.  19.58616
# 16     2055                         PETROMAX, S.A. DE C.V.  25.67880
# 17     2056              GASOLINERA HUITEPEC, S.A. DE C.V.  16.73187
# 18     2057                         PETROMAX, S.A. DE C.V.  26.01390
# 19     2058  ENERGIA Y SERVICIOS COORDINADOS, S.A. DE C.V.  24.02956
#
#     longitude regular premium diesel
# 0  -116.92140   20.99   24.99  23.39
# 1   -99.74484   22.81   24.03    NaN
# 2  -106.45140   17.65   20.07    NaN
# 3  -103.30420   22.14     NaN    NaN
# 4   -98.29977   18.19     NaN    NaN
# 5  -117.07150   21.59   24.99    NaN
# 6  -108.96850   24.05   25.11    NaN
# 7  -100.29180   22.59     NaN    NaN
# 8  -116.60790   21.39   24.69  23.19
# 9  -117.04570   21.69   24.49    NaN
# 10 -100.18400   23.49     NaN    NaN
# 11 -101.41890   21.89   24.75    NaN
# 12  -97.44485   17.59    16.6    NaN
# 13 -105.19470   23.99     NaN  25.29
# 14 -117.02710   21.79   24.99    NaN
# 15  -99.19730   21.99   24.79    NaN
# 16 -100.23650   22.99     NaN    NaN
# 17  -92.65437    22.3     NaN    NaN
# 18  -98.20425   18.19     NaN    NaN
# 19 -104.62170   23.19   25.09  24.69

# %%
df_refactored.count()
# Out:
# place_id     13303
# name         13303
# latitude     13303
# longitude    13303
# regular      13243
# premium       5102
# diesel        3857
# dtype: int64

# %%
# Save into csv
df_refactored.to_csv('refactored_dataset.csv', index=False)
